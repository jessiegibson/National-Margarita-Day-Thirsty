# %%
import pandas as pd
import requests
import logging
import time

logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

#------------------ CONFIGURATION -------------------------------

# Set your Google API key here. 
# Even if using the free 2500 queries a day, its worth getting an API key since the rate limit is 50 / second.
# With API_KEY = None, you will run into a 2 second delay every 10 requests or so.
# With a "Google Maps Geocoding API" key from https://console.developers.google.com/apis/, 
# the daily limit will be 2500, but at a much faster rate.
# Example: API_KEY =# Backoff time sets how many minutes to wait between google pings when your API limit is hit
BACKOFF_TIME = 30
# Set your output file name here.
output_filename = 'margarita_day_final.csv'
# Set your input file here
input_filename = "margarita_day_test.csv"
# Specify the column name in your input data that contains addresses here
address_column_name = "address"
# Return Full Google Results? If True, full JSON results from Google are included in output
RETURN_FULL_RESULTS = False

data = pd.read_csv(input_filename)

# Confirms that there is a column named 
if address_column_name not in data.columns:
    raise ValueError("Missing Address Column in input data")

    addresses = data[address_column_name].tolist()

# %%
#------------------ DATA LOADING --------------------------------

# Read the data to a Pandas Dataframe
data = pd.read_csv(input_filename, encoding='utf8')

if address_column_name not in data.columns:
	raise ValueError("Missing Address column in input data")

# Form a list of addresses for geocoding:
# Make a big list of all of the addresses to be processed.
addresses = data[address_column_name].tolist()

# **** DEMO DATA / IRELAND SPECIFIC! ****
# We know that these addresses are in Ireland, and there's a column for county, so add this for accuracy. 
# (remove this line / alter for your own dataset)
addresses = (data[address_column_name]).tolist()

addresses
# Out:
# ['221 smith st.,Brooklyn,NY,',
#  '4 bleeker st.,New York,NY,',
#  '197 2nd ave.,New York,NY,',
#  '18 spring st.,New York,NY,',
#  '105 1st ave.,New York,NY,',
#  '94 avenue a,New York,NY,',
#  '128 w houston,New York,NY,',
#  '190 w. 4th st.,New York,NY,',
#  '123 lexington ave.,New York,NY,',
#  '2122 beekman pl.,Brooklyn,NY,',
#  '2727 indian creek dr,Miami,FL,33140',
#  '437 sw 2nd st,Miami,FL,33130',
#  '820 Alton Rd, Miami Beach, FL 33139',
#  '3456 n miami ave,Miami,FL,33127',
#  '971 sw 8th st,Miami,FL,33130',
#  '1690 collins ave,Miami Beach,FL,33139',
#  '75 se 6th st,Miami,FL,33131',
#  '251 nw 25th st,Miami,FL,33137',
#  '237 20th st ste b,Miami Beach,FL,33139',
#  '2637 n miami ave,Miami,FL,33127',
#  '500 brickell ave ste d,Miami,FL,33131',
#  '2727 indian creek dr,Miami Beach,FL,33140',
#  '207 ne 1st st,Miami,FL,33132',
#  '205 westshore plaza,Tampa,FL,',
#  '365 main st,Dunedin,FL,',
#  '911 central ave,St Petersburg,FL,',
#  '1704 E 7th Ave,Tampa,FL,',
#  '1327 e 7th ave,Tampa,FL,',
#  '633 n franklin st,Tampa,FL,',
#  '1878 sylvan ave ste e150,Dallas,TX,75208',
#  '2010 greenville ave,Dallas,TX,75206',
#  '2008 greenville ave,Dallas,TX,75206',
#  '2614 boll st,Dallas,TX,75204',
#  '3090 oliver st ste b 110,Dallas,TX,75205',
#  '604 n tyler st,Dallas,TX,75208',
#  '1617 hi line dr,Dallas,TX,75207',
#  '605 brazos st,Austin,TX,78701',
#  '307 w 5th st,Austin,TX,78701',
#  '3100 fannin st #115,Houston,TX,77004',
#  '5802 fulton st,Houston,TX,77009',
#  '1010 banks st,Houston,TX,77006',
#  '1919 greenville ave,Dallas,TX,75206',
#  '1530 main st,Dallas,TX,75201',
#  '2714 elm st,Dallas,TX,75226',
#  '1914 greenville ave,Dallas,TX,75206',
#  '1915 greenville ave,Dallas,TX,75207',
#  '5855 maple ave ste 190,Dallas,TX,75235',
#  '400 crescent ct,Dallas,TX,75201',
#  '9028 garland rd,Dallas,TX,75218',
#  '1601 main st,Dallas,TX,75201',
#  '1607 pacific ave,Venice,CA,90291',
#  '1263 w temple st,Los Angeles,CA,90026',
#  '1927 hillhurst ave,Los Angeles,CA,90027',
#  '9010 melrose ave,West Hollywood,CA,90069',
#  '416 w 8th st,Los Angeles,CA,90014',
#  '7465 melrose ave,Los Angeles,CA,90046',
#  '12477 w washington blvd,Los Angeles,CA,90066',
#  '107 e 6th st,Los Angeles,CA,90014',
#  '1228 sunset blvd,Los Angeles,CA,90026',
#  '5221 hollywood blvd,Los Angeles,CA,90027',
#  '5635 n figueroa st,Los Angeles,CA,90042',
#  '1540 sunset blvd,Los Angeles,CA,90026',
#  '7360 beverly blvd,Los Angeles,CA,90036',
#  '1115 e wardlow rd,Long Beach,CA,90807',
#  '1117 e wardlow rd,Long Beach,CA,90807',
#  '136 e anaheim st,Long Beach,CA,90813',
#  '820 w 19th st,,Costa Mesa,CA,92627',
#  '891 baker st,Costa Mesa,CA,92626',
#  '1816 1⁄2 n. vermont ave,Los Feliz,CA,90027',
#  '3250 adams ave,San Diego,CA,',
#  '1503 30th st,San Diego,CA,',
#  '1250 prospect st,La Jolla,CA,',
#  '4612 park blvd,San Diego,CA,',
#  '3926 30th st,San Diego,CA,',
#  '2414 san diego ave,San Diego,CA,',
#  '748 fifth ave,San Diego,CA,92101',
#  '2725 state st,Carlsbad,CA,92008',
#  '948 n western ave,Chicago,IL,',
#  '1270 n milwaukee ave,Chicago,IL,',
#  '226 w chicago ave,Chicago,IL,',
#  '11 w illinois st,Chicago,IL,',
#  '2528 n california ave,Chicago,IL,',
#  '565 w randolph st,Chicago,IL,',
#  '948 w fulton market,Chicago,IL,',
#  '694 n milwaukee ave,Chicago,IL,',
#  '201 e delaware pl,Chicago,IL,',
#  '3137 W Logan Blvd,Chicago,IL,',
#  '1726 s racine ave,Chicago,IL,',
#  '2545 n kedzie ave,Chicago,IL,',
#  '2914 n clark st,Chicago,IL,',
#  '2800 w logan blvd,Chicago,IL,',
#  '660 w lake st,Chicago,IL,',
#  '1802 s allport st,Chicago,IL,',
#  '459 n ogden ave,Chicago,IL,',
#  '2548 n southport ave,Chicago,IL,',
#  '300 santana row,San Jose,CA,',
#  '632 emerson st,Palo Alto,CA,',
#  '2250 Chestnut St,San Francisco,CA,',
#  '1548 Stockton St,San Francisco,CA,',
#  '741 Valencia St,San Francisco,CA,',
#  '52 e santa clara st,San Jose,CA,',
#  '25 w san fernando st,San Jose,CA,',
#  '1541 pacific ave ste b,Santa Cruz,CA,',
#  'dolores street, between 5th and, 6th ave,Carmel,CA,',
#  '3627 san pablo ave,Emeryville,CA,',
#  '72 S 1st St,San Jose,CA,',
#  '7 Sanborn Ct, Somerville, MA 02143',
#  '3 Beacon St, Somerville, MA 02143',
#  '170 W Broadway,Boston,MA,',
#  '292 Massachusetts Ave,Cambridge,MA,',
#  '21 Drydock Ave,Boston ,MA,',
#  '500 Commonwealth Ave ,Boston,MA,',
#  '52 Church St,Cambridge,MA,',
#  '175 Rivers Edge Drive,Medford,MA,',
#  '69 Bromfield St,Boston,MA,',
#  '514 UNION ST. ,Brooklyn,NY,',
#  '29 E. 2ND ST.,New York,NY,',
#  '1 W. 3RD ST.,New York,NY,',
#  '59 GRAND ST.,New York,NY,',
#  '195 BEDFORD AVE.,Brooklyn,NY,',
#  '510 HUDSON ST. ,New York,NY,',
#  '371 Broome St ,New York,NY,',
#  '45 W. 35TH ST.,New York,NY,',
#  '444 PARK AVE S. ,New York,NY,',
#  '127 Loisaida Ave,New York,NY,',
#  '4216 Oak Lawn Ave, Dallas, TX',
#  '3858 Oak Lawn Ave #470, Dallas, TX',
#  '2912 N. Henderson Ave, Dallas, TX',
#  '1617 Hi Line Dr. Unit 395, Dallas, TX',
#  '1914 E 6th St ste c, Austin, TX 78702',
#  '2027 Anchor Ln, Austin, TX 78723']

# %%
#------------------	FUNCTION DEFINITIONS ------------------------

def get_google_results(address, api_key=None, return_full_response=False):
    """
    Get geocode results from Google Maps Geocoding API.
    
    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.
    
    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google. 
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
#------------------ PROCESSING LOOP -----------------------------

# Ensure, before we start, that the API key is ok/valid, and internet access is ok
test_result = get_google_results("London, England", API_KEY, RETURN_FULL_RESULTS)
if (test_result['status'] != 'OK') or (test_result['formatted_address'] != 'London, UK'):
    logger.warning("There was an error when testing the Google Geocoder.")
    raise ConnectionError('Problem with test results from Google Geocode - check your API key and internet connection.')

# Create a list to hold results
results = []
# Go through each address in turn
for address in addresses:
    # While the address geocoding is not finished:
    geocoded = False
    while geocoded is not True:
        # Geocode the address with google
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)           
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
    	logger.info("Completed {} of {} address".format(len(results), len(addresses)))
            
    # Every 500 addresses, save progress to file(in case of a failure so you have something!)
    if len(results) % 500 == 0:
        pd.DataFrame(results).to_csv("{}_bak".format(output_filename))

# All done
logger.info("Finished geocoding all addresses")
# Write the full results to csv using the pandas library.
pd.DataFrame(results).to_csv(output_filename, encoding='utf8')
# Out:
# Geocoded: 221 smith st.,Brooklyn,NY,: OK
# Geocoded: 4 bleeker st.,New York,NY,: OK
# Geocoded: 197 2nd ave.,New York,NY,: OK
# Geocoded: 18 spring st.,New York,NY,: OK
# Geocoded: 105 1st ave.,New York,NY,: OK
# Geocoded: 94 avenue a,New York,NY,: OK
# Geocoded: 128 w houston,New York,NY,: OK
# Geocoded: 190 w. 4th st.,New York,NY,: OK
# Geocoded: 123 lexington ave.,New York,NY,: OK
# Geocoded: 2122 beekman pl.,Brooklyn,NY,: OK
# Geocoded: 2727 indian creek dr,Miami,FL,33140: OK
# Geocoded: 437 sw 2nd st,Miami,FL,33130: OK
# Geocoded: 820 Alton Rd, Miami Beach, FL 33139: OK
# Geocoded: 3456 n miami ave,Miami,FL,33127: OK
# Geocoded: 971 sw 8th st,Miami,FL,33130: OK
# Geocoded: 1690 collins ave,Miami Beach,FL,33139: OK
# Geocoded: 75 se 6th st,Miami,FL,33131: OK
# Geocoded: 251 nw 25th st,Miami,FL,33137: OK
# Geocoded: 237 20th st ste b,Miami Beach,FL,33139: OK
# Geocoded: 2637 n miami ave,Miami,FL,33127: OK
# Geocoded: 500 brickell ave ste d,Miami,FL,33131: OK
# Geocoded: 2727 indian creek dr,Miami Beach,FL,33140: OK
# Geocoded: 207 ne 1st st,Miami,FL,33132: OK
# Geocoded: 205 westshore plaza,Tampa,FL,: OK
# Geocoded: 365 main st,Dunedin,FL,: OK
# Geocoded: 911 central ave,St Petersburg,FL,: OK
# Geocoded: 1704 E 7th Ave,Tampa,FL,: OK
# Geocoded: 1327 e 7th ave,Tampa,FL,: OK
# Geocoded: 633 n franklin st,Tampa,FL,: OK
# Geocoded: 1878 sylvan ave ste e150,Dallas,TX,75208: OK
# Geocoded: 2010 greenville ave,Dallas,TX,75206: OK
# Geocoded: 2008 greenville ave,Dallas,TX,75206: OK
# Geocoded: 2614 boll st,Dallas,TX,75204: OK
# Geocoded: 3090 oliver st ste b 110,Dallas,TX,75205: OK
# Geocoded: 604 n tyler st,Dallas,TX,75208: OK
# Geocoded: 1617 hi line dr,Dallas,TX,75207: OK
# Geocoded: 605 brazos st,Austin,TX,78701: OK
# Geocoded: 307 w 5th st,Austin,TX,78701: OK
# Error geocoding 3100 fannin st #115,Houston,TX,77004: REQUEST_DENIED
# Geocoded: 3100 fannin st #115,Houston,TX,77004: REQUEST_DENIED
# Geocoded: 5802 fulton st,Houston,TX,77009: OK
# Geocoded: 1010 banks st,Houston,TX,77006: OK
# Geocoded: 1919 greenville ave,Dallas,TX,75206: OK
# Geocoded: 1530 main st,Dallas,TX,75201: OK
# Geocoded: 2714 elm st,Dallas,TX,75226: OK
# Geocoded: 1914 greenville ave,Dallas,TX,75206: OK
# Geocoded: 1915 greenville ave,Dallas,TX,75207: OK
# Geocoded: 5855 maple ave ste 190,Dallas,TX,75235: OK
# Geocoded: 400 crescent ct,Dallas,TX,75201: OK
# Geocoded: 9028 garland rd,Dallas,TX,75218: OK
# Geocoded: 1601 main st,Dallas,TX,75201: OK
# Geocoded: 1607 pacific ave,Venice,CA,90291: OK
# Geocoded: 1263 w temple st,Los Angeles,CA,90026: OK
# Geocoded: 1927 hillhurst ave,Los Angeles,CA,90027: OK
# Geocoded: 9010 melrose ave,West Hollywood,CA,90069: OK
# Geocoded: 416 w 8th st,Los Angeles,CA,90014: OK
# Geocoded: 7465 melrose ave,Los Angeles,CA,90046: OK
# Geocoded: 12477 w washington blvd,Los Angeles,CA,90066: OK
# Geocoded: 107 e 6th st,Los Angeles,CA,90014: OK
# Geocoded: 1228 sunset blvd,Los Angeles,CA,90026: OK
# Geocoded: 5221 hollywood blvd,Los Angeles,CA,90027: OK
# Geocoded: 5635 n figueroa st,Los Angeles,CA,90042: OK
# Geocoded: 1540 sunset blvd,Los Angeles,CA,90026: OK
# Geocoded: 7360 beverly blvd,Los Angeles,CA,90036: OK
# Geocoded: 1115 e wardlow rd,Long Beach,CA,90807: OK
# Geocoded: 1117 e wardlow rd,Long Beach,CA,90807: OK
# Geocoded: 136 e anaheim st,Long Beach,CA,90813: OK
# Geocoded: 820 w 19th st,,Costa Mesa,CA,92627: OK
# Geocoded: 891 baker st,Costa Mesa,CA,92626: OK
# Geocoded: 1816 1⁄2 n. vermont ave,Los Feliz,CA,90027: OK
# Geocoded: 3250 adams ave,San Diego,CA,: OK
# Geocoded: 1503 30th st,San Diego,CA,: OK
# Geocoded: 1250 prospect st,La Jolla,CA,: OK
# Geocoded: 4612 park blvd,San Diego,CA,: OK
# Geocoded: 3926 30th st,San Diego,CA,: OK
# Geocoded: 2414 san diego ave,San Diego,CA,: OK
# Geocoded: 748 fifth ave,San Diego,CA,92101: OK
# Geocoded: 2725 state st,Carlsbad,CA,92008: OK
# Geocoded: 948 n western ave,Chicago,IL,: OK
# Geocoded: 1270 n milwaukee ave,Chicago,IL,: OK
# Geocoded: 226 w chicago ave,Chicago,IL,: OK
# Geocoded: 11 w illinois st,Chicago,IL,: OK
# Geocoded: 2528 n california ave,Chicago,IL,: OK
# Geocoded: 565 w randolph st,Chicago,IL,: OK
# Geocoded: 948 w fulton market,Chicago,IL,: OK
# Geocoded: 694 n milwaukee ave,Chicago,IL,: OK
# Geocoded: 201 e delaware pl,Chicago,IL,: OK
# Geocoded: 3137 W Logan Blvd,Chicago,IL,: OK
# Geocoded: 1726 s racine ave,Chicago,IL,: OK
# Geocoded: 2545 n kedzie ave,Chicago,IL,: OK
# Geocoded: 2914 n clark st,Chicago,IL,: OK
# Geocoded: 2800 w logan blvd,Chicago,IL,: OK
# Geocoded: 660 w lake st,Chicago,IL,: OK
# Geocoded: 1802 s allport st,Chicago,IL,: OK
# Geocoded: 459 n ogden ave,Chicago,IL,: OK
# Geocoded: 2548 n southport ave,Chicago,IL,: OK
# Geocoded: 300 santana row,San Jose,CA,: OK
# Geocoded: 632 emerson st,Palo Alto,CA,: OK
# Geocoded: 2250 Chestnut St,San Francisco,CA,: OK
# Geocoded: 1548 Stockton St,San Francisco,CA,: OK
# Geocoded: 741 Valencia St,San Francisco,CA,: OK
# Completed 100 of 131 address
# Geocoded: 52 e santa clara st,San Jose,CA,: OK
# Geocoded: 25 w san fernando st,San Jose,CA,: OK
# Geocoded: 1541 pacific ave ste b,Santa Cruz,CA,: OK
# Geocoded: dolores street, between 5th and, 6th ave,Carmel,CA,: OK
# Geocoded: 3627 san pablo ave,Emeryville,CA,: OK
# Geocoded: 72 S 1st St,San Jose,CA,: OK
# Geocoded: 7 Sanborn Ct, Somerville, MA 02143: OK
# Geocoded: 3 Beacon St, Somerville, MA 02143: OK
# Geocoded: 170 W Broadway,Boston,MA,: OK
# Geocoded: 292 Massachusetts Ave,Cambridge,MA,: OK
# Geocoded: 21 Drydock Ave,Boston ,MA,: OK
# Geocoded: 500 Commonwealth Ave ,Boston,MA,: OK
# Geocoded: 52 Church St,Cambridge,MA,: OK
# Geocoded: 175 Rivers Edge Drive,Medford,MA,: OK
# Geocoded: 69 Bromfield St,Boston,MA,: OK
# Geocoded: 514 UNION ST. ,Brooklyn,NY,: OK
# Geocoded: 29 E. 2ND ST.,New York,NY,: OK
# Geocoded: 1 W. 3RD ST.,New York,NY,: OK
# Geocoded: 59 GRAND ST.,New York,NY,: OK
# Geocoded: 195 BEDFORD AVE.,Brooklyn,NY,: OK
# Geocoded: 510 HUDSON ST. ,New York,NY,: OK
# Geocoded: 371 Broome St ,New York,NY,: OK
# Geocoded: 45 W. 35TH ST.,New York,NY,: OK
# Geocoded: 444 PARK AVE S. ,New York,NY,: OK
# Geocoded: 127 Loisaida Ave,New York,NY,: OK
# Geocoded: 4216 Oak Lawn Ave, Dallas, TX: OK
# Error geocoding 3858 Oak Lawn Ave #470, Dallas, TX: REQUEST_DENIED
# Geocoded: 3858 Oak Lawn Ave #470, Dallas, TX: REQUEST_DENIED
# Geocoded: 2912 N. Henderson Ave, Dallas, TX: OK
# Geocoded: 1617 Hi Line Dr. Unit 395, Dallas, TX: OK
# Geocoded: 1914 E 6th St ste c, Austin, TX 78702: OK
# Geocoded: 2027 Anchor Ln, Austin, TX 78723: OK
# Finished geocoding all addresses
